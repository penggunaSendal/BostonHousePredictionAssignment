# %%
import numpy as np
import pandas as pd
import os

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pandas import read_csv

column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
csv = read_csv('./housing.csv', header=None, delimiter=r'\s+', names=column_names)

data = pd.DataFrame(csv)

data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
print(data.shape)
# Out:
# (506, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# EDA

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
sns.pairplot(data, height=2.5)
plt.tight_layout()

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()

for k, v in data.items():
  sns.boxplot(y=k, data=data, ax=axs[index])
  index += 1

plt.tight_layout()

# %%
# Checking outliers percentage

for k, v in data.items():
  q1 = v.quantile(0.25)
  q3 = v.quantile(0.75)
  irq = q3 - q1

  v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
  perc = np.shape(v_col)[0] * 100.0 / np.shape(data)[0]

  print('Column {} outliers = {:.2f}%'.format(k, perc))
# Out:
# Column CRIM outliers = 13.04%
# Column ZN outliers = 13.44%
# Column INDUS outliers = 0.00%
# Column CHAS outliers = 100.00%
# Column NOX outliers = 0.00%
# Column RM outliers = 5.93%
# Column AGE outliers = 0.00%
# Column DIS outliers = 0.99%
# Column RAD outliers = 0.00%
# Column TAX outliers = 0.00%
# Column PTRATIO outliers = 2.96%
# Column B outliers = 15.22%
# Column LSTAT outliers = 1.38%
# Column MEDV outliers = 7.91%

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20,10))
index = 0
axs = axs.flatten()

for k, v in data.items():
  sns.distplot(v, ax=axs[index])
  index += 1

plt.tight_layout()
# Out:
# C:\Users\malik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\malik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#checking skewness & kurtosis

index = 0

for k, v in data.items():
  print('Feature {} Skewness = {:.7f}'.format(k, data[k].skew()))
  print('Feature {} Kurtosis = {:.7f}'.format(k, data[k].kurt()))
  index += 1
# Out:
# Feature CRIM Skewness = 5.2231488
# Feature CRIM Kurtosis = 37.1305091
# Feature ZN Skewness = 2.2256663
# Feature ZN Kurtosis = 4.0315101
# Feature INDUS Skewness = 0.2950216
# Feature INDUS Kurtosis = -1.2335396
# Feature CHAS Skewness = 3.4059042
# Feature CHAS Kurtosis = 9.6382638
# Feature NOX Skewness = 0.7293079
# Feature NOX Kurtosis = -0.0646671
# Feature RM Skewness = 0.4036121
# Feature RM Kurtosis = 1.8915004
# Feature AGE Skewness = -0.5989626
# Feature AGE Kurtosis = -0.9677156
# Feature DIS Skewness = 1.0117806
# Feature DIS Kurtosis = 0.4879411
# Feature RAD Skewness = 1.0048146
# Feature RAD Kurtosis = -0.8672320
# Feature TAX Skewness = 0.6699559
# Feature TAX Kurtosis = -1.1424080
# Feature PTRATIO Skewness = -0.8023249
# Feature PTRATIO Kurtosis = -0.2850914
# Feature B Skewness = -2.8903737
# Feature B Kurtosis = 7.2268175
# Feature LSTAT Skewness = 0.9064601
# Feature LSTAT Kurtosis = 0.4932395
# Feature MEDV Skewness = 1.1080984
# ...

# %%
# try removing MEDV that >= 50 in the original dataset MEDV more than 50 cencored

# data = data[~(data['MEDV'] >= 50.0)]
# print(data.shape())

# aborted because somehow reducing accuracy (more MSE)

# %%
from scipy import stats
from scipy.stats import norm, skew

fig, axs = plt.subplots()
index = 0

for k, v in data.items():
  sns.distplot(data[k], fit=norm)

  (mu, sigma) = norm.fit(data[k])
  print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

  plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='best')

  fig = plt.figure()
  res = stats.probplot(data[k], plot=plt)
  plt.xlabel('{} Theoritical Quantiles'.format(k))
  plt.show()

  index += 1
# Out:
#  mu = 3.61 and sigma = 8.59
# C:\Users\malik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#  mu = 11.36 and sigma = 23.30
# C:\Users\malik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#  mu = 11.14 and sigma = 6.85
# ...

# %%
sns.distplot(data['MEDV'], fit=norm)

(mu, sigma) = norm.fit(data['MEDV'])
print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.xlabel('MEDV Dist.')

fig = plt.figure()
res = stats.probplot(data['MEDV'], plot = plt)
plt.show()
# Out:
# C:\Users\malik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#  mu = 22.53 and sigma = 9.19

# %%
# i try to remove skewness on MEDV

data['MEDV'] = np.log1p(data['MEDV'])

sns.distplot(data['MEDV'], fit=norm)

(mu, sigma) = norm.fit(data['MEDV'])
print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.xlabel('MEDV Dist.')

fig = plt.figure()
res = stats.probplot(data['MEDV'], plot = plt)
plt.show()
# Out:
#  mu = 3.09 and sigma = 0.39
# C:\Users\malik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20, 10))

cor = data.corr().abs()
sns.heatmap(cor, annot=True)
plt.show()

# %%
cor_target = abs(cor['MEDV'])
relevant_features = cor_target[cor_target > 0.2]
feature_names = [index for index, value in relevant_features.iteritems()]

feature_names.remove('MEDV')

print(feature_names)
print(len(feature_names))
# Out:
# ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# 12

# %%
from sklearn import preprocessing

min_max_scaller = preprocessing.MinMaxScaler()
column_cels = feature_names

x = data.loc[:,column_cels]
y = data['MEDV']

x = pd.DataFrame(data=min_max_scaller.fit_transform(x), columns=column_cels)
fig, axs = plt.subplots(ncols=6, nrows=2, figsize=(30, 10))
index = 0
axs = axs.flatten()

for i, k in enumerate(column_cels):
  sns.regplot(y=y, x=x[k], ax=axs[i])

plt.tight_layout()

# %%
# try to remove skewness from above X through log transformation

# y = np.log1p(y)

# for col in x.columns:
#   if np.abs(x[col.skew()]) > 0.3:
#     x[col] = np.log1p(x[col])

# aborted because reducing accuracy

# %%
# MODEL BUILDING

# %%
# SPLITTING TEST AND TRAIN DATASET

from sklearn.model_selection import train_test_split

x = data[feature_names]
y = data['MEDV']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 12)
# (102, 12)
# (404,)
# (102,)

# %%
# Linear Regression

from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(x_test)

print('Actual Value of The House = $ {}'.format(y_test[0]))
print('Model Prediction Value of The House = $ {}'.format(prediction[0]))
# Out:
# Actual Value of The House = $ 3.2188758248682006
# Model Prediction Value of The House = $ 3.374248487683637

# %%
from sklearn.metrics import mean_squared_error

score_map = {}

Linear_Regression_mse = mean_squared_error(y_test, prediction)
Linear_Regression_rmse = np.sqrt(Linear_Regression_mse)

score_map['LinearRegression'] = Linear_Regression_mse, Linear_Regression_rmse

print('MSE = {}'.format(Linear_Regression_mse))
print('RMSE = {}'.format(Linear_Regression_rmse))
# Out:
# MSE = 0.036147770714176325
# RMSE = 0.19012567084477658

# %%
# Support Vector Regression

from sklearn.svm import SVR

svr = SVR()

svr.fit(x_train, y_train)
# Out:
# SVR()

# %%
svr_predic = svr.predict(x_test)

print('Actual Value of The House = $ {}'.format(y_test[0]))
print('Model Prediction Value of The House = $ {}'.format(svr_predic[0]))
# Out:
# Actual Value of The House = $ 3.2188758248682006
# Model Prediction Value of The House = $ 3.1726058146355234

# %%
svr_mse = mean_squared_error(y_test, svr_predic)
svr_rmse = np.sqrt(svr_mse)

score_map['SVR'] = svr_mse, svr_rmse

print('MSE = {}'.format(svr_mse))
print('RMSE = {}'.format(svr_rmse))
# Out:
# MSE = 0.06493588444529551
# RMSE = 0.25482520370892575

# %%
# KNeighborsRegression

from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor()

knr.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knr_prediction = knr.predict(x_test)

print('Actual Value of The House = $ {}'.format(y_test[0]))
print('Model Prediction Value of The House = $ {}'.format(knr_prediction[0]))
# Out:
# Actual Value of The House = $ 3.2188758248682006
# Model Prediction Value of The House = $ 3.2343655351031644

# %%
knr_mse = mean_squared_error(y_test, knr_prediction)
knr_rmse = np.sqrt(knr_mse)

score_map['KNeighborsRegressor'] = knr_mse, knr_rmse

print('MSE = {}'.format(knr_mse))
print('RMSE = {}'.format(knr_rmse))
# Out:
# MSE = 0.04865843762215618
# RMSE = 0.22058657625104067

# %%
# DEcision ttree regressor

from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor(max_depth=5)

dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
dtr_predict = dtr.predict(x_test)


print('Actual Value of The House = $ {}'.format(y_test[0]))
print('Model Prediction Value of The House = $ {}'.format(dtr_predict[0]))
# Out:
# Actual Value of The House = $ 3.2188758248682006
# Model Prediction Value of The House = $ 3.2317871814637513

# %%
dtr_mse = mean_squared_error(y_test, dtr_predict)
dtr_rmse = np.sqrt(dtr_mse)

score_map['DecisionTreeRegressor'] = dtr_mse, dtr_rmse

print('MSE = {}'.format(dtr_mse))
print('RMSE = {}'.format(dtr_rmse))
# Out:
# MSE = 0.03468549853053781
# RMSE = 0.18624043205098567

# %%
# gradient boost

from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()

gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
gbr_predict = gbr.predict(x_test)


print('Actual Value of The House = $ {}'.format(y_test[0]))
print('Model Prediction Value of The House = $ {}'.format(gbr_predict[0]))
# Out:
# Actual Value of The House = $ 3.2188758248682006
# Model Prediction Value of The House = $ 3.211827474460664

# %%
gbr_mse = mean_squared_error(y_test, gbr_predict)
gbr_rmse = np.sqrt(gbr_mse)

score_map['GradientBoostingRegressor'] = gbr_mse, gbr_rmse

print('MSE = {}'.format(gbr_mse))
print('RMSE = {}'.format(gbr_rmse))
# Out:
# MSE = 0.0193828754542555
# RMSE = 0.1392223956633971

# %%
score_ALL_map = pd.DataFrame(score_map, index=['MSE', 'RMSE'])

score_ALL_map
# Out:
#       LinearRegression       SVR  KNeighborsRegressor  DecisionTreeRegressor  \
# MSE           0.036148  0.064936             0.048658               0.034685
# RMSE          0.190126  0.254825             0.220587               0.186240
#
#       GradientBoostingRegressor
# MSE                    0.019383
# RMSE                   0.139222

# %%
plt.figure(figsize=(15, 10))

ax = sns.boxplot(data=score_ALL_map)

ax.set_title('Model Performance Comparison')
# Out:
# Text(0.5, 1.0, 'Model Performance Comparison')
